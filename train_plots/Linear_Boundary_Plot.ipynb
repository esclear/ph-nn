# %% [markdown]
# ### Port-Hamiltonian Optimizer
# Copyright (c) 2020. Daniel Albert. Published under the GNU General Public License.
#
# This notebook will explore the feasibility of learning a linear boundary with the Port-Hamiltonian based optimizer.
# The distribution is created and seeded with the same parameters as the one by Massaroli et al., such that we may directly compare the results obtained.

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf
import tensorflow.keras as keras

from sklearn.model_selection import train_test_split

from PHNetworks.PHOptimizer import PortHamiltonianOptimizer as PHOpt, _model_set_flat_variables
from tf_plot_callback import Plotter

# %% [markdown]
# Create some test data

# %%
N = 1000

np.random.seed(1)
X1 = np.random.multivariate_normal([0.6, 0.7], [[0.025, 0.0], [0.0, 0.01]], N)
Y1 = np.hstack((np.ones((N, 1)), np.zeros((N, 1))))

np.random.seed(2)
X2 = np.random.multivariate_normal([0.1, 0.2], [[0.025, -0.00], [-0.00, 0.01]], N)
Y2 = np.hstack((np.zeros((N, 1)), np.ones((N, 1))))

X = np.vstack((X1,X2))
Y = np.vstack((Y1,Y2))

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.25, random_state=42)

x_range = (X_train.min(0)[0], X_train.max(0)[0])
y_range = (X_train.min(0)[1], X_train.max(0)[1])

# %%
plt.figure(figsize=(6,5))

plt.scatter(X1[:,0],X1[:,1],label='$X_1$', rasterized=False, s=8, c='#00aecf')
plt.scatter(X2[:,0],X2[:,1],label='$X_2$', rasterized=False, s=8, c='#489324')
plt.xlabel("$x_1$")
plt.ylabel("$x_2$")
plt.xlim(x_range)
plt.ylim(y_range)
plt.legend();

plt.savefig('training_data.pdf')

# %% [markdown]
# Construct a tiny, linear network with two inputs. The network structure and loss function are the same as in the paper.

# %%
def get_model():
    # The model consists of just two input neurons and two linear output neurons
    model = keras.models.Sequential(layers=[
        keras.layers.Dense(2, input_shape=(2,), name='input_layer', dtype='float64')
    ])

    # The loss function is the sum of squared differences
    @tf.function
    def loss(y_pred, y_true):
        return tf.math.reduce_sum(tf.math.square(y_pred - y_true))

    model.compile(loss=loss)
    
    # Print summary
    model.summary()
    
    # Initialize the model with the same parameters as the original paper did
    _model_set_flat_variables(model, tf.constant([0.6, -2.3, -0.1, -1.1, -1.2, 0.3], dtype='float64'))
    
    return model

# %% [markdown]
# Train the model for 100 units of time.
# The optimizer is configured for an integration period of t* = 0.025 time units with a step size of Δt = 0.025, so in every epoch, only a single step is taken.
# This is done so that we can plot the hamiltonian, loss, accuracy and network parameters / velocities in after every integration step using only the callbacks integrated into the optimizer and keeping the integrator simple and efficient at the same time.
#
# However, the optimization is run for 400 epochs, so in total we integrate for 100 units of time.
# It is important to note here, that the batch size is set up as 1500 samples.
# Due to this configuration, we integrate in "batch mode" and therefore always integrate the system with the same Hamiltonian.
# Since the integrator remembers the velocities between batches and epochs, this is exactly equivalent to integrating over a single epoch, but for 100 units of time.

# %%
model = get_model()
optimizer = PHOpt(alpha=1.0, beta=0.5, gamma=0.5, resistive=25, ivp_period=0.025, ivp_step_size=0.025)

# The following is not intended usage, but lets us reproduce the starting conditions as given in the paper exactly:
optimizer._check_model_and_state(model)
optimizer._integrator.velocity.assign(tf.constant([-1.2, 0.3, 0.2, 1.6, -0.4, 1.6], shape=(6,1), dtype='float64'))

plotter = Plotter(optimizer.ivp_period, model, optimizer._integrator)

train_log_dir = 'classifier_logs'

tensorboard_callback = keras.callbacks.TensorBoard(log_dir=train_log_dir, update_freq=1, profile_batch=0)

with tf.device('/gpu:0'):
    optimizer.train(model, X_train, Y_train, batch_size=1500, metrics=[keras.metrics.CategoricalAccuracy()], callbacks=[plotter], epochs=400, verbose=False)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_layer (Dense)          (None, 2)                 6
# =================================================================
# Total params: 6
# Trainable params: 6
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Okay, the training's done.
#
# From the output above, we see that the single training epoch took 2 seconds.
#
# The training reports 99.83% categorical accuracy, i.e. that 99.83% of points within the _training_ dataset were categorized correctly.
#
# Let's plot the points in the _testing_ dataset and find out whether they are classified correctly.

# %%
num_p = 100

u1 = np.linspace(*x_range, num_p)
u2 = np.linspace(*y_range, num_p)

U1, U2 = np.meshgrid(u1, u2)
Z = np.zeros((num_p, num_p))

# Formula for the border of the two zones. Hand-derived from the equations for the output neuron's activations
# This is used to color the two zones in the model
def f(x):
    w = model.weights[0]
    b = model.weights[1]
    return ((w[0,1] - w[0,0]) * x + b[1] - b[0]) / (w[1,0] - w[1,1])


plt.figure(figsize=(6,5))

split = f(u1)

plt.fill_between(u1, y_range[0], split, color='#489324', alpha=0.4, lw=0)
plt.fill_between(u1, split, y_range[1], color='#00aecf', alpha=0.4, lw=0)

X1_test = X_test[Y_test[:,0] >= Y_test[:,1]]
X2_test = X_test[Y_test[:,0] <  Y_test[:,1]]

Y_test_m = model(X_test)

plt.scatter(X1_test[:,0], X1_test[:,1], label='$X_1$', rasterized=False, s=8, c='#00aecf')
plt.scatter(X2_test[:,0], X2_test[:,1], label='$X_2$', rasterized=False, s=8, c='#489324')

plt.xlabel("$x_1$")
plt.ylabel("$x_2$")
plt.xlim(x_range)
plt.ylim(y_range);

plt.savefig('trained_boundary.pdf')

# %% [markdown]
# In the graphic it seems that all points of the test set were classified correctly.
# To validate this:

# %%
ca = tf.keras.metrics.CategoricalAccuracy()
ca.update_state(Y_test, Y_test_m)
ca.result()
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=1.0>

# %% [markdown]
# Thus, 100 % of the points in our test set have been categorized correctly.
#
# Now, looking at the whole dataset, the combined training and testing datasets:

# %%
plt.figure(figsize=(6,5))

split = f(u1)

plt.fill_between(u1, y_range[0], split, color='#489324', alpha=0.4, lw=0)
plt.fill_between(u1, split, y_range[1], color='#00aecf', alpha=0.4, lw=0)

X1_test = X_test[Y_test[:,0] >= Y_test[:,1]]
X2_test = X_test[Y_test[:,0] <  Y_test[:,1]]

Y_m = model(X)

plt.scatter(X1[:,0], X1[:,1], label='$X_1$', rasterized=False, s=8, c='#00aecf')
plt.scatter(X2[:,0], X2[:,1], label='$X_2$', rasterized=False, s=8, c='#489324')

plt.xlabel("$x_1$")
plt.ylabel("$x_2$")
plt.xlim(x_range)
plt.ylim(y_range)

plt.show()

# %% [markdown]
# It seems that only two (of 2000) points being categorized incorrectly.
# Validating this:

# %%
ca.reset_states()
ca.update_state(Y, Y_m)
ca.result()
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=0.999>

# %% [markdown]
# So we have obtained a classification accuracy of 99.9 %.

# %%
plot = plotter.plot()

# %% [markdown]
# Looks okay so far, but I also want to add labels for the parameters, at least for a model with so little parameters:

# %%
plot.get_axes()[2].legend([f'$\\vartheta_{i}$' for i in range(1, 7)], bbox_to_anchor=(1.01, 0.45), loc='upper left', borderaxespad=0.);
plot

# %%
plot.savefig('params_plot_linear_classifier_basic.pdf')

# %% [markdown]
# The previous example is one where we have a very large resistive factor of 25, while the weight, γ, was set to only 0.5.
# Next, let's look at the behaviour of the training process when using a higher weights (and thus larger impulses of parameters) and a lower resistive factor:

# %%
model = get_model()
optimizer = PHOpt(alpha=1.0, beta=0.5, gamma=1.2, resistive=1.2, ivp_period=0.025, ivp_step_size=0.025)

# The following is not intended usage, but lets us reproduce the starting conditions as given in the paper exactly:
optimizer._check_model_and_state(model)
optimizer._integrator.velocity.assign(tf.constant([-1.2, 0.3, 0.2, 1.6, -0.4, 1.6], shape=(6,1), dtype='float64'))

plotter = Plotter(optimizer.ivp_period, model, optimizer._integrator)

train_log_dir = 'classifier_logs'

tensorboard_callback = keras.callbacks.TensorBoard(log_dir=train_log_dir, update_freq=1, profile_batch=0)

with tf.device('/gpu:0'):
    optimizer.train(model, X_train, Y_train, batch_size=1500, metrics=[keras.metrics.CategoricalAccuracy()], callbacks=[plotter], epochs=400, verbose=False)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_layer (Dense)          (None, 2)                 6
# =================================================================
# Total params: 6
# Trainable params: 6
# Non-trainable params: 0
# _________________________________________________________________

# %%
plot = plotter.plot()

# %%
plot.get_axes()[2].legend([f'$\\vartheta_{i}$' for i in range(1, 7)], bbox_to_anchor=(1.01, 0.45), loc='upper left', borderaxespad=0.);
plot

# %%
plot.savefig('params_plot_linear_classifier_heavier.pdf')

# %% [markdown]
# Also, check the accuracy for this network as well:

# %%
ca.reset_states()
ca.update_state(Y, Y_m)
ca.result()
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=0.999>

# %% [markdown]
# This is also 99.9 % and therefore the trained network's performance is comparable to the first network (and even identical on the data in our samples).
